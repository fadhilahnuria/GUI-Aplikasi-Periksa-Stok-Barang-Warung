# %% [markdown]
# Tugas Projek Akhir SDA Kelompok 7 Sains Data 2022A
#
# Nama Anggota Kelompok:
# 1. Fadhilah Nuria Shinta    22031554003
# 2. Daffa Fazly Rashidan     22031554006
# 3. DhaniAditya Putra E.     22031554038

# %%
#import library
from tkinter import *            # Untuk membuat GUI
from PIL import ImageTk, Image   # Untuk membaca Gambar
from tkinter import ttk          # Untuk mengatur style widget
import pandas as pd              # untuk membaca dan menyimpan csv
from tkinter import messagebox   # untuk menampilkan showinfo
# from docx import Document        # untuk menyimpan entryan ke document
import datetime as dt            # untuk menampilkan tanggal bulan dan tahun pada dataset
import customtkinter             # untuk memperbagus button, combobox
import os 
os.system('cls')


class newproject:
    def __init__(self,master):
        self.window=master
        # self.window.geometry('1166x718')
        # self.window.resizable(1, 1)
        self.window.state('zoomed')#Digunakan karena layar auto fullscreen dan bisa di minimize dan maximize
        self.window.title('NEW PROJECT')#Judul Program
        self.window.configure(bg='#ccc6ba')

        

        #kasibg
        
    def regispage(self):
        def regis2():
            #kondisi mewajibkan semua entry terisi dengan baik
            if self.nama_depan_entry.get() and self.nama_belakang_entry.get() and self.email_entry.get()and self.password_entry.get() and self.jabatan_box.get() and self.nomor_entry.get() and self.konfirmasipw_entry.get():
                dataset = pd.read_csv('data_user1.csv')
                # Membuat list seluruh email yg ada di csv
                email = []
                for x in dataset.email:
                    email.append(x)
                    
                #jika ada email yang sama pada data set
                if self.email_entry.get() in email:
                    self.wajib = Label(self.register_frame, background='#f4eee0', text='Email telah digunakan!',fg='red', font=("yu gothic ui", 12), relief=FLAT, width=49, height=1)
                    self.wajib.place(x=670, y=530)
    # Fungsi diatas untuk memeriksa apakah semua masukan (entry) telah diisi dengan benar. Jika semua masukan telah diisi dengan benar
    # kode kemudian membaca data dari file CSV 'data_user1.csv' menggunakan Pandas. Data email dari file CSV tersebut disimpan dalam sebuah daftar.
    # Kemudian, memeriksa apakah email yang dimasukkan pada self.email_entry terdapat dalam daftar email. Jika email sudah digunakan sebelumnya,
    # kode akan menampilkan pesan kesalahan pada jendela pendaftaran. 


                else:
                    #nomor telfon yang diinputkan harus berupa angka
                    nomortelfon=self.nomor_entry.get()
                    if nomortelfon.isdigit():
                        nomortelf=[]
                        for y in dataset.nomor:
                            nomortelf.append(y)
                            
                        #mengubah widget entry pada nomor harus dinputkan berupa angka
                        if self.nomor_entry.get() in nomortelf:
                            self.wajib = Label(self.register_frame, background='#f4eee0', text='Nomor telfon telah digunakan!',fg='red', font=("yu gothic ui", 12), relief=FLAT, width=49, height=1)
                            self.wajib.place(x=670, y=530)
    # jika email yang dimasukkan tidak ada dalam daftar email yang ada, maka kode akan melanjutkan dengan kondisi lain.
    # Kode memeriksa apakah nomor telepon yang dimasukkan berupa angka. Jika iya, maka kode akan melanjutkan dengan pengecekan lebih lanjut.
    # Setelah itu, kode membaca nomor telepon dari dataset yang ada dan menyimpannya dalam daftar nomortelf.
    # Lalu memeriksa apakah nomor telepon yang dimasukkan pada self.nomor_entry sudah ada dalam daftar nomortelf.
    # Jika nomor telepon tersebut sudah digunakan sebelumnya, kode akan menampilkan pesan kesalahan 


                        else:   
                            jabatan=[]
                            for z in dataset.jabatan:
                                jabatan.append(z)
                                
                            if self.jabatan_box.get() == 'Manajer' and 'Manajer' in jabatan:
                                self.wajib = Label(self.register_frame, background='#f4eee0', text='*Manajer sudah ada',fg='#191825', font=("yu gothic ui", 12), relief=FLAT, width=49, height=1)
                                self.wajib.place(x=670, y=530)
    # Jika nomor telepon yang dimasukkan bukan berupa angka atau nomor telepon sudah digunakan sebelumnya, maka blok kode else akan dieksekusi.
    # Kode akan membaca jabatan dari dataset yang ada dan menyimpannya dalam daftar jabatan.
    # Lalu akan diperiksa apakah nilai yang dipilih pada self.jabatan_box adalah "Manajer" dan apakah "Manajer" sudah ada dalam daftar jabatan
    # Jika kondisi tersebut terpenuhi, maka kode akan menampilkan pesan kesalahan yang sesuai pada jendela pendaftaran


                            else:   
                                if "@" in self.email_entry.get():
                                    if self.password_entry.get() == self.konfirmasipw_entry.get():
                                        #menyimpan data dari index
                                        dataset.loc[len(dataset.index)] = [self.nama_depan_entry.get(),  self.nama_belakang_entry.get(), self.email_entry.get(),   self.nomor_entry.get(), self.jabatan_box.get(), self.password_entry.get()]
                                        dataset.to_csv("data_user1.csv", index=False, header=True)
                # Memeriksa apakah karakter "@" ada dalam email yang dimasukkan. Bertujuan untuk memvalidasi apakah email yang dimasukkan memiliki format yang sesuai. 
                # Jika karakter "@" ada dalam email yang dimasukkan, akan dilanjut dengan pengecekan berikutnya.
                # Lalu memeriksa apakah nilai yang dimasukkan pada self.password_entry sama dgn nilai yang dimasukkan pada self.konfirmasipw_entry.
                # Jika kedua kondisi di atas terpenuhi, maka selanjutnya Data dari masukan (nama depan, nama belakang, email, nomor telepon, jabatan, dan password) disimpan dalam dataset.
                # Dataset kemudian disimpan ke dalam file CSV "data_user1.csv" dengan menggunakan metode to_csv dari pustaka Pandas.


                                        #Frame timpa dari register
                                        self.timpa_frame = Frame(self.register_frame, bg='#1d0529', width=1460, height=779)
                                        self.timpa_frame.place(x=0,y=0)
                                        
                                        #Frame
                                        self.lg_frame = Frame(self.timpa_frame, bg='#f4eee0', width=1460, height=779)
                                        self.lg_frame.place(x=0,y=0)
                                        self.bgrn_image = ImageTk.PhotoImage(Image.open('gambar/bgrn2new.png'))
                                        self.bgrn2 = Label(self.lg_frame, image=self.bgrn_image, background="#ccc6ba").place(x=0, y=0)
                # Pertama membuat frame baru dengan nama timpa_frame. Frame ini merupakan anak dari register_frame, yang merupakan frame pendaftaran.
                # Selanjutnya, dibuat frame baru dengan nama lg_frame di dalam timpa_frame
                # Lalu code self.bgrn_image = ImageTk.PhotoImage(Image.open('gambar/bgrn2new.png')) digunakan untuk membuka gambar 'bgrn2new.png'
                # dan membuat objek gambar bgrn_image menggunakan pustaka PIL. Gambar ini akan digunakan sebagai latar belakang frame.
                # kode terakhir yakni digunakan untuk membuat label dengan menggunakan gambar bgrn_image sebagai gambarnya.


                                        #Email
                                        self.email_label = Label(self.lg_frame, text="Email", bg="#e2ddce", fg="white",
                                                                    font=("yu gothic ui", 30, "bold",))
                                        self.email_label.place(x=690, y=180)
                                        self.email_entry = Entry(self.lg_frame, highlightthickness=0, relief=FLAT, bg="white", fg="#999999",
                                                                    font=("yu gothic ui ", 30, "bold"))
                                        self.email_entry.place(x=495, y=237, width=500)

                                        #Password
                                        self.password_label = Label(self.lg_frame, text="Password", bg="#e2ddce", fg="white",
                                                                    font=("yu gothic ui", 30, "bold",))
                                        self.password_label.place(x=650, y=318)
                                        self.password_entry = Entry(self.lg_frame, highlightthickness=0, relief=FLAT, bg="white", fg="#999999",
                                                                    font=("yu gothic ui ", 30, "bold"))
                                        self.password_entry.place(x=495, y=380, width=500)
                                        self.password_entry.config(show='*')
                                        
                                        #login button 
                                        def show():
                                            self.hide_button = Button(self.lg_frame, image=self.hide_image, relief=FLAT,
                                                                    activebackground="white",command=hide
                                                                    , borderwidth=0, background="white", cursor="hand2")
                                            self.hide_button.place(x=970, y=395)
                                            self.password_entry.config(show='')

                                        def hide():
                                            self.show_button = Button(self.lg_frame, image=self.show_image, command=show, relief=FLAT,
                                                                    activebackground="white"
                                                                    , borderwidth=0, background="white", cursor="hand2")
                                            self.show_button.place(x=970, y=395)
                                            self.password_entry.config(show='*')
                                                    
                                        # Gambar Show & hide
                                        self.show_image = ImageTk.PhotoImage(Image.open('gambar/show.png'))
                                        self.hide_image = ImageTk.PhotoImage(Image.open('gambar/hide.png'))
                                        self.show_button = Button(self.lg_frame, image=self.show_image, command=show, relief=FLAT,
                                                                activebackground="white"
                                                                , borderwidth=0, background="white", cursor="hand2")
                                        self.show_button.image = self.show_image
                                        self.show_button.place(x=970, y=395)    
                                
                                        # Login Button
                                        self.login=customtkinter.CTkButton(master=self.lg_frame, text='Login',font=('Courier New', 20), corner_radius=13,text_color="White", width=500, height=50, fg_color="#181b29", hover_color="#444352", command=self.mainpage).place(x=495, y=500)

                                        
                                        #Nothaveaccount
                                        self.already = Label(self.lg_frame, text="Not have account yet?", bg="#f4eee0", fg="white",
                                                                    font=("yu gothic ui", 15, "bold"))
                                        self.already.place(x=495, y=555)

                                        #button back register
                                        self.sign_in_button = Button(self.lg_frame, text="Daftar disini",font=("yu gothic ui", 15, "bold underline"), fg="#12009c", relief=FLAT,activebackground="#f4eee0", borderwidth=0, background="#f4eee0", cursor="hand2",command=regis2)
                                        self.sign_in_button.place(x=487, y=595)


                                    #jika konfirmasi password tidak sama   
                                    else:
                                        self.wajib = Label(self.register_frame, background='#f4eee0', text='*Password dengan konfirmasi pasword tidak sama',fg='red', font=("yu gothic ui", 12,'italic'), relief=FLAT, width=49, height=1)
                                        self.wajib.place(x=670, y=530)

                                #Jika Email ditulis tanpa menggunakan @
                                else:
                                    self.wajib = Label(self.register_frame, background='#f4eee0', text='Pastikan menulis e-mail dengan benar',
                                    fg='red', font=("yu gothic ui", 12,'italic'), relief=FLAT, width=49, height=1)
                                    self.wajib.place(x=670, y=530)
                    #Jika notelfon ditulis menggunakan huruf
                    else:
                        self.wajib = Label(self.register_frame, background='#f4eee0', text='Tulis nomor telepon dengan benar!',fg='red', font=("yu gothic ui", 12,'italic'), relief=FLAT, width=49, height=1)
                        self.wajib.place(x=670, y=530)
                    
            #jika ada entry yang tidak ter isi dengan benar        
            else:
                self.wajib = Label(self.register_frame, background='#f4eee0', text='*Semua entry harus di isi',
                            fg="#191825", font=("yu gothic ui", 12,'bold','italic'), relief=FLAT, width=49, height=1)
                self.wajib.place(x=790, y=630)

            
            # Frame
            self.register_frame = Frame(self.window, bg='#f4eee0', width=1460, height=779)
            self.register_frame.place(x=35, y=35)
            self.bgrn_image = ImageTk.PhotoImage(Image.open('gambar/bgrnnew.png'))
            self.bgrnlabl= Label(self.register_frame, image=self.bgrn_image, background="#ccc6ba").place(x=0, y=0)
            
            #Logo
            photo_logo = ImageTk.PhotoImage(Image.open('gambar/lgperusahaan.png'))
            self.logo_label = Label(self.register_frame, image=photo_logo, bg='#f4eee0')
            self.logo_label.image = photo_logo
            self.logo_label.place(x=540, y=20)
            
            #NamaDepan
            self.nama_depan_label = Label(self.register_frame, text="Nama Depan", bg="#f4eee0", fg="#181b29",
                                        font=("Roboto Bold", 20, "bold"))
            self.nama_depan_label.place(x=270, y=200)
            self.nama_depan_entry = Entry(self.register_frame,highlightthickness=0, relief=FLAT, bg="white", fg="#999999",
                                        font=("yu gothic ui", 25, "bold"))
            self.nama_depan_entry.place(x=270, y=245, width=350, height=50)
            
            #Nama Belakang
            self.nama_belakang_label = Label(self.register_frame, text="Nama Belakang", bg="#f4eee0", fg="#181b29",
                                        font=("Roboto Bold", 20, "bold"))
            self.nama_belakang_label.place(x=800, y=200)
            self.nama_belakang_entry = Entry(self.register_frame, highlightthickness=0, relief=FLAT, bg="white", fg="#999999",
                                        font=("yu gothic ui ", 25, "bold"))
            self.nama_belakang_entry.place(x=800, y=245, width=350, height=50)
            
            #Jabatan
            self.jabatan_label = Label(self.register_frame,text='Jabatan',bg="#f4eee0",fg='#181b29'
                                    ,font=('Roboto Bold',20,'bold'))
            self.jabatan_label.place(x=270,y=320)
            self.list_jabatan = ["Karyawan", "Manajer"]
            self.jabatan_box = ttk.Combobox(self.register_frame,values=self.list_jabatan,font=("yu gothic ui ", 25))
            self.jabatan_box.place(x=270, y=360 ,height=50,width=350)
            
            #no handphone pribadi
            self.nomor_label = Label(self.register_frame, text="No handphone Pribadi", bg="#f4eee0", fg="#181b29",
                                        font=("Roboto Bold", 20, "bold"))
            self.nomor_label.place(x=800, y=320)
            self.nomor_entry = Entry(self.register_frame, highlightthickness=0, relief=FLAT, bg="white", fg="#999999",
                                        font=("yu gothic ui ", 25, "bold"))
            self.nomor_entry.place(x=800, y=360, width=350, height=50)
            
            #Email
            self.email_label = Label(self.register_frame, text="Email", bg="#f4eee0", fg="#181b29",
                                        font=("Roboto Bold", 20, "bold"))
            self.email_label.place(x=270, y=425)
            self.email_entry = Entry(self.register_frame, highlightthickness=0, relief=FLAT, bg="white", fg="#999999",
                                        font=("yu gothic ui ", 25, "bold"))
            self.email_entry.place(x=270, y=463, width=350, height=50)
            
            #Password
            self.password_label = Label(self.register_frame, text="Password", bg="#f4eee0", fg="#181b29",
                                        font=("Roboto Bold", 20, "bold"))
            self.password_label.place(x=800, y=425)
            self.password_entry = Entry(self.register_frame, highlightthickness=0, relief=FLAT, bg="white", fg="#999999",
                                        font=("yu gothic ui ", 25, "bold"))
            self.password_entry.place(x=800, y=463, width=350, height=50)
            self.password_entry.config(show='*')
            
            # Gambar Show & hide
            self.show_image = ImageTk.PhotoImage(Image.open('gambar/show.png'))
            self.hide_image = ImageTk.PhotoImage(Image.open('gambar/hide.png'))

            def show():
                self.hide_button = Button(self.register_frame, image=self.hide_image, relief=FLAT,
                                            activebackground="white",command=hide
                                            , borderwidth=0, background="white", cursor="hand2")
                self.hide_button.place(x=1130, y=475)
                self.password_entry.config(show='')
                self.konfirmasipw_entry.config(show='')

            def hide():
                self.show_button = Button(self.register_frame, image=self.show_image, command=show, relief=FLAT,
                                            activebackground="white"
                                            , borderwidth=0, background="white", cursor="hand2")
                self.show_button.place(x=1130, y=475)
                self.password_entry.config(show='*')
                self.konfirmasipw_entry.config(show='*')
            
            #GAMBAR AWAL SHOW BUTTON
            self.show_button = Button(self.register_frame, image=self.show_image, command=show, relief=FLAT,
                                    activebackground="white"
                                    , borderwidth=0, background="white", cursor="hand2")
            self.show_button.place(x=1130, y=475)   
            
            #KonfirmPassword
            self.konfirmasipw_label = Label(self.register_frame, text="konfirmasi Password", bg="#f4eee0", fg="#181b29",
                                        font=("Roboto Bold", 20, "bold"))
            self.konfirmasipw_label.place(x=270, y=530)
            self.konfirmasipw_entry = Entry(self.register_frame, highlightthickness=0, relief=FLAT, bg="white", fg="#999999",
                                        font=("yu gothic ui ", 25, "bold"))
            self.konfirmasipw_entry.place(x=270, y=570, width=350, height=45)
            self.konfirmasipw_entry.config(show='*')

            #Label notice konfirmasipw
            self.notifkonfirmasi_label = Label(self.register_frame,text='*pastikan mengisi password dengan benar',bg="#f4eee0", fg="#181b29",
                                        font=("yu gothic ui", 10, "bold",'italic'))
            self.notifkonfirmasi_label.place(x=620,y=580)
            
            #registerButton
            self.btnregis=customtkinter.CTkButton(master=self.register_frame, text='Register Now',font=('Courier New', 20), corner_radius=13,text_color="White", width=520, height=30, fg_color="#181b29", hover_color="#444352", command=login).place(x=270, y=630)
            
            # Already have an account
            self.already = Label(self.register_frame, text="Already have an account?", bg="#f4eee0", fg="#181b29",
                                        font=("yu gothic ui", 16, "bold"))
            self.already.place(x=270, y=670)
            
            # Login Button
            self.login_button = Button(self.register_frame, text="Login",font=("yu gothic ui", 15, "bold underline"), fg="#12009c", relief=FLAT,activebackground="#f4eee0", borderwidth=0, background="#f4eee0", cursor="hand2",command=accountready)
            self.login_button.place(x=530, y=668)
        

        def accountready():
            #Frame
            self.lg_frame = Frame(self.register_frame, bg='#f4eee0', width=1460, height=779)
            self.lg_frame.place(x=0,y=0)
            self.bgrn_image = ImageTk.PhotoImage(Image.open('gambar/bgrn2new.png'))
            self.bgrn2 = Label(self.lg_frame, image=self.bgrn_image, background="#ccc6ba").place(x=0, y=0)
            
            #Email
            self.email_label = Label(self.lg_frame, text="Email", bg="#e2ddce", fg="#181b29",
                                        font=("yu gothic ui", 30, "bold",))
            self.email_label.place(x=690, y=180)
            self.email_entry = Entry(self.lg_frame, highlightthickness=0, relief=FLAT, bg="white", fg="#999999",
                                        font=("yu gothic ui ", 30, "bold"))
            self.email_entry.place(x=495, y=237, width=500)

            #Password
            self.password_label = Label(self.lg_frame, text="Password", bg="#e2ddce", fg="#181b29",
                                        font=("yu gothic ui", 30, "bold",))
            self.password_label.place(x=650, y=318)
            self.password_entry = Entry(self.lg_frame, highlightthickness=0, relief=FLAT, bg="white", fg="#999999",
                                        font=("yu gothic ui ", 30, "bold"))
            self.password_entry.place(x=495, y=380, width=500)
            self.password_entry.config(show='*')
            
            #login button 
            def show():
                self.hide_button = Button(self.lg_frame, image=self.hide_image, relief=FLAT,
                                        activebackground="white",command=hide
                                        , borderwidth=0, background="white", cursor="hand2")
                self.hide_button.place(x=970, y=395)
                self.password_entry.config(show='')

            def hide():
                self.show_button = Button(self.lg_frame, image=self.show_image, command=show, relief=FLAT,
                                        activebackground="white"
                                        , borderwidth=0, background="white", cursor="hand2")
                self.show_button.place(x=970, y=395)
                self.password_entry.config(show='*')
                        
            # Gambar Show & hide
            self.show_image = ImageTk.PhotoImage(Image.open('gambar/show.png'))
            self.hide_image = ImageTk.PhotoImage(Image.open('gambar/hide.png'))
            self.show_button = Button(self.lg_frame, image=self.show_image, command=show, relief=FLAT,
                                    activebackground="white"
                                    , borderwidth=0, background="white", cursor="hand2")
            self.show_button.image = self.show_image
            self.show_button.place(x=970, y=395)    
    
            # Login Button
            self.login=customtkinter.CTkButton(master=self.lg_frame, text='Login',font=('Courier New', 20),text_color="White", corner_radius=13, width=500, height=50, fg_color="#181b29", hover_color="#444352", command=self.mainpage).place(x=495, y=500)

            
            #Nothaveaccount
            self.already = Label(self.lg_frame, text="Not have account yet?", bg="#e2ddce", fg="#181b29",
                                        font=("yu gothic ui", 15, "bold"))
            self.already.place(x=495, y=555)

            #button back register
            self.sign_in_button = Button(self.lg_frame, text="Daftar disini",font=("yu gothic ui", 15, "bold underline"), fg="#12009c", relief=FLAT,activebackground="#e2ddce", borderwidth=0, background="#e2ddce", cursor="hand2",command=regis2)
            self.sign_in_button.place(x=487, y=595)

        def login():
            #kondisi mewajibkan semua entry terisi dengan baik
            if self.nama_depan_entry.get() and self.nama_belakang_entry.get() and self.email_entry.get()and self.password_entry.get() and self.jabatan_box.get() and self.nomor_entry.get() and self.konfirmasipw_entry.get():
                dataset = pd.read_csv('data_user1.csv')
                # Membuat list seluruh email yg ada di csv
                email = []
                for x in dataset.email:
                    email.append(x)
                    
                #jika ada email yang sama pada data set
                if self.email_entry.get() in email:
                    self.wajib = Label(self.register_frame, background='#f4eee0', text='Email telah digunakan!',fg='red', font=("yu gothic ui", 12), relief=FLAT, width=30, height=1)
                    self.wajib.place(x=380,y=425)
    # Fungsi diatas untuk memeriksa apakah semua masukan (entry) telah diisi dengan benar. Jika semua masukan telah diisi dengan benar
    # kode kemudian membaca data dari file CSV 'data_user1.csv' menggunakan Pandas. Data email dari file CSV tersebut disimpan dalam sebuah daftar
    # Kemudian, memeriksa apakah email yang dimasukkan pada self.email_entry terdapat dalam daftar email. Jika email sudah digunakan sebelumnya,
    # kode akan menampilkan pesan kesalahan pada jendela pendaftaran. 


                else:
                    #nomor telfon yang diinputkan harus berupa angka
                    nomortelfon=self.nomor_entry.get()
                    if nomortelfon.isdigit():
                        nomortelf=[]
                        for y in dataset.nomor:
                            nomortelf.append(y)
                            
                        #mengubah widget entry pada nomor harus dinputkan berupa angka
                        if self.nomor_entry.get() in nomortelf:
                            self.wajib = Label(self.register_frame, background='#f4eee0', text='Nomor telfon telah digunakan!',fg='red', font=("yu gothic ui", 12), relief=FLAT, width=49, height=1)
                            self.wajib.place(x=670, y=530)

                        else:   
                            jabatan=[]
                            for z in dataset.jabatan:
                                jabatan.append(z)
                                
                            if self.jabatan_box.get() == 'Manajer' and 'Manajer' in jabatan:
                                self.wajib = Label(self.register_frame, background='#f4eee0', text='*Manajer sudah ada',fg='red', font=("yu gothic ui", 12), relief=FLAT, width=30, height=1)
                                self.wajib.place(x=380,y=320)
                            
                            else:   
                                if "@" in self.email_entry.get():
                                    if self.password_entry.get() == self.konfirmasipw_entry.get():
                                        #menyimpan data dari index
                                        dataset.loc[len(dataset.index)] = [self.nama_depan_entry.get(),  self.nama_belakang_entry.get(), self.email_entry.get(),   self.nomor_entry.get(), self.jabatan_box.get(), self.password_entry.get()]
                                        dataset.to_csv("data_user1.csv", index=False, header=True)

                                        #Frame timpa dari register
                                        self.timpa_frame = Frame(self.register_frame, bg='#1d0529', width=1460, height=779)
                                        self.timpa_frame.place(x=0,y=0)
                                        
                                        #Frame
                                        self.lg_frame = Frame(self.timpa_frame, bg='#f4eee0', width=1460, height=779)
                                        self.lg_frame.place(x=0,y=0)
                                        self.bgrn_image = ImageTk.PhotoImage(Image.open('gambar/bgrn2new.png'))
                                        self.bgrn2 = Label(self.lg_frame, image=self.bgrn_image, background="#ccc6ba").place(x=0, y=0)

                                    
                                                            
                                        #Email
                                        self.email_label = Label(self.lg_frame, text="Email", bg="#e2ddce", fg="#181b29",
                                                                    font=("yu gothic ui", 30, "bold",))
                                        self.email_label.place(x=690, y=180)
                                        self.email_entry = Entry(self.lg_frame, highlightthickness=0, relief=FLAT, bg="white", fg="#999999",
                                                                    font=("yu gothic ui ", 30, "bold"))
                                        self.email_entry.place(x=495, y=237, width=500)

                                        #Password
                                        self.password_label = Label(self.lg_frame, text="Password", bg="#e2ddce", fg="#181b29",
                                                                    font=("yu gothic ui", 30, "bold",))
                                        self.password_label.place(x=650, y=318)
                                        self.password_entry = Entry(self.lg_frame, highlightthickness=0, relief=FLAT, bg="white", fg="#999999",
                                                                    font=("yu gothic ui ", 30, "bold"))
                                        self.password_entry.place(x=495, y=380, width=500)
                                        self.password_entry.config(show='*')
                                        
                                        #login button 
                                        def show():
                                            self.hide_button = Button(self.lg_frame, image=self.hide_image, relief=FLAT,
                                                                    activebackground="white",command=hide
                                                                    , borderwidth=0, background="white", cursor="hand2")
                                            self.hide_button.place(x=970, y=395)
                                            self.password_entry.config(show='')

                                        def hide():
                                            self.show_button = Button(self.lg_frame, image=self.show_image, command=show, relief=FLAT,
                                                                    activebackground="white"
                                                                    , borderwidth=0, background="white", cursor="hand2")
                                            self.show_button.place(x=970, y=395)
                                            self.password_entry.config(show='*')
                                                    
                                        # Gambar Show & hide
                                        self.show_image = ImageTk.PhotoImage(Image.open('gambar/show.png'))
                                        self.hide_image = ImageTk.PhotoImage(Image.open('gambar/hide.png'))
                                        self.show_button = Button(self.lg_frame, image=self.show_image, command=show, relief=FLAT,
                                                                activebackground="white"
                                                                , borderwidth=0, background="white", cursor="hand2")
                                        self.show_button.image = self.show_image
                                        self.show_button.place(x=970, y=395)    
                                
                                        # Login Button

                                        self.login=customtkinter.CTkButton(master=self.lg_frame, text='Login',font=('Courier New', 20),text_color="White", corner_radius=13, width=500, height=50, fg_color="#181b29", hover_color="#444352", command=self.mainpage).place(x=495, y=500)

                                        
                                        #Nothaveaccount
                                        self.already = Label(self.lg_frame, text="Not have account yet?", bg="#e2ddce", fg="#181b29",
                                                                    font=("yu gothic ui", 15, "bold"))
                                        self.already.place(x=495, y=555)

                                        #button back register
                                        self.sign_in_button = Button(self.lg_frame, text="Daftar disini",font=("yu gothic ui", 15, "bold underline"), fg="#12009c", relief=FLAT,activebackground="#f4eee0", borderwidth=0, background="#e2ddce", cursor="hand2",command=regis2)
                                        self.sign_in_button.place(x=487, y=595)

                                    
                                    #jika konfirmasi password tidak sama   
                                    else:
                                        self.wajib = Label(self.register_frame, background='#f4eee0', text='*Password dengan konfirmasi pasword tidak sama',fg='red', font=("yu gothic ui", 12,'italic'), relief=FLAT, width=49, height=1)
                                        self.wajib.place(x=670, y=530)

                                #Jika Email ditulis tanpa menggunakan @
                                else:
                                    self.wajib = Label(self.register_frame, background='#f4eee0', text='Pastikan menulis e-mail dengan benar',
                                    fg='red', font=("yu gothic ui", 12,'italic'), relief=FLAT, width=49, height=1)
                                    self.wajib.place(x=670, y=530)
                    #Jika notelfon ditulis menggunakan huruf
                    else:
                        self.wajib = Label(self.register_frame, background='#f4eee0', text='Tulis nomor telepon dengan benar!',fg='red', font=("yu gothic ui", 12,'italic'), relief=FLAT, width=49, height=1)
                        self.wajib.place(x=670, y=530)
                    
            #jika ada entry yang tidak ter isi dengan benar        
            else:
                self.wajib = Label(self.register_frame, background='#f4eee0', text='*Semua entry harus di isi',
                            fg="#191825", font=("yu gothic ui", 12,'bold','italic'), relief=FLAT, width=30, height=1)
                self.wajib.place(x=820, y=630)

            
        
            
        
        # Frame
        self.register_frame = Frame(self.window, bg='#f4eee0', width=1460, height=779)
        self.register_frame.place(x=35, y=35)
        self.bgrn_image = ImageTk.PhotoImage(Image.open('gambar/bgrnnew.png'))
        self.bgrnlabl= Label(self.register_frame, image=self.bgrn_image, background="#ccc6ba").place(x=0, y=0)
        
        #Logo
        photo_logo = ImageTk.PhotoImage(Image.open('gambar/lgperusahaan.png'))
        self.logo_label = Label(self.register_frame, image=photo_logo, bg='#f4eee0')
        self.logo_label.image = photo_logo
        self.logo_label.place(x=540, y=20)
        
        #NamaDepan
        self.nama_depan_label = Label(self.register_frame, text="Nama Depan", bg="#f4eee0", fg="#181b29",
                                    font=("Roboto Bold", 20, "bold"))
        self.nama_depan_label.place(x=270, y=200)
        self.nama_depan_entry = Entry(self.register_frame,highlightthickness=0, relief=FLAT, bg="white", fg="#999999",
                                    font=("yu gothic ui", 25, "bold"))
        self.nama_depan_entry.place(x=270, y=245, width=350, height=50)
        
        #Nama Belakang
        self.nama_belakang_label = Label(self.register_frame, text="Nama Belakang", bg="#f4eee0", fg="#181b29",
                                    font=("Roboto Bold", 20, "bold"))
        self.nama_belakang_label.place(x=800, y=200)
        self.nama_belakang_entry = Entry(self.register_frame, highlightthickness=0, relief=FLAT, bg="white", fg="#999999",
                                    font=("yu gothic ui ", 25, "bold"))
        self.nama_belakang_entry.place(x=800, y=245, width=350, height=50)
        
        #Jabatan
        self.jabatan_label = Label(self.register_frame,text='Jabatan',bg="#f4eee0",fg='#181b29'
                                   ,font=('Roboto Bold',20,'bold'))
        self.jabatan_label.place(x=270,y=320)
        self.list_jabatan = ["Karyawan", "Manajer"]
        self.jabatan_box = ttk.Combobox(self.register_frame,values=self.list_jabatan,font=("yu gothic ui ", 25))
        self.jabatan_box.place(x=270, y=360 ,height=50,width=350)
        
        #no handphone pribadi
        self.nomor_label = Label(self.register_frame, text="No handphone Pribadi", bg="#f4eee0", fg="#181b29",
                                    font=("Roboto Bold", 20, "bold"))
        self.nomor_label.place(x=800, y=320)
        self.nomor_entry = Entry(self.register_frame, highlightthickness=0, relief=FLAT, bg="white", fg="#999999",
                                    font=("yu gothic ui ", 25, "bold"))
        self.nomor_entry.place(x=800, y=360, width=350, height=50)
        
        #Email
        self.email_label = Label(self.register_frame, text="Email", bg="#f4eee0", fg="#181b29",
                                    font=("Roboto Bold", 20, "bold"))
        self.email_label.place(x=270, y=425)
        self.email_entry = Entry(self.register_frame, highlightthickness=0, relief=FLAT, bg="white", fg="#999999",
                                    font=("yu gothic ui ", 25, "bold"))
        self.email_entry.place(x=270, y=463, width=350, height=50)
        
        #Password
        self.password_label = Label(self.register_frame, text="Password", bg="#f4eee0", fg="#181b29",
                                    font=("Roboto Bold", 20, "bold"))
        self.password_label.place(x=800, y=425)
        self.password_entry = Entry(self.register_frame, highlightthickness=0, relief=FLAT, bg="white", fg="#999999",
                                    font=("yu gothic ui ", 25, "bold"))
        self.password_entry.place(x=800, y=463, width=350, height=50)
        self.password_entry.config(show='*')
        
        # Gambar Show & hide
        self.show_image = ImageTk.PhotoImage(Image.open('gambar/show.png'))
        self.hide_image = ImageTk.PhotoImage(Image.open('gambar/hide.png'))

        def show():
            self.hide_button = Button(self.register_frame, image=self.hide_image, relief=FLAT,
                                        activebackground="white",command=hide
                                        , borderwidth=0, background="white", cursor="hand2")
            self.hide_button.place(x=1130, y=475)
            self.password_entry.config(show='')
            self.konfirmasipw_entry.config(show='')

        def hide():
            self.show_button = Button(self.register_frame, image=self.show_image, command=show, relief=FLAT,
                                        activebackground="white"
                                        , borderwidth=0, background="white", cursor="hand2")
            self.show_button.place(x=1130, y=475)
            self.password_entry.config(show='*')
            self.konfirmasipw_entry.config(show='*')
        #GAMBAR AWAL SHOW BUTTON
        self.show_button = Button(self.register_frame, image=self.show_image, command=show, relief=FLAT,
                                activebackground="white"
                                , borderwidth=0, background="white", cursor="hand2")
        self.show_button.place(x=1130, y=475)   
        
        #KonfirmPassword
        self.konfirmasipw_label = Label(self.register_frame, text="konfirmasi Password", bg="#f4eee0", fg="#181b29",
                                    font=("Roboto Bold", 20, "bold"))
        self.konfirmasipw_label.place(x=270, y=530)
        self.konfirmasipw_entry = Entry(self.register_frame, highlightthickness=0, relief=FLAT, bg="white", fg="#999999",
                                    font=("yu gothic ui ", 25, "bold"))
        self.konfirmasipw_entry.place(x=270, y=570, width=350, height=45)
        self.konfirmasipw_entry.config(show='*')
        #Label notice konfirmasipw
        self.notifkonfirmasi_label = Label(self.register_frame,text='*pastikan mengisi password dengan benar',bg="#f4eee0", fg="#181b29",
                                    font=("yu gothic ui", 10, "bold",'italic'))
        self.notifkonfirmasi_label.place(x=620,y=580)
        
        #registerButton
        self.btnregis=customtkinter.CTkButton(master=self.register_frame, text='Register Now',font=('Courier New', 20), corner_radius=13,text_color="White", width=520, height=30, fg_color="#181b29", hover_color="#444352", command=login).place(x=270, y=630)
        
        # Already have an account
        self.already = Label(self.register_frame, text="Already have an account?", bg="#f4eee0", fg="#181b29",
                                    font=("yu gothic ui", 16, "bold"))
        self.already.place(x=270, y=670)
        
        # Login Button
        self.login_button = Button(self.register_frame, text="Login",font=("yu gothic ui", 15, "bold underline"), fg="#12009c", relief=FLAT,activebackground="#f4eee0", borderwidth=0, background="#f4eee0", cursor="hand2",command=accountready)
        self.login_button.place(x=530, y=668)
    
    def mainpage(self):
        def dedmart():
            if dataset.jabatan[self.idx]=='Karyawan':
                def template():
                    data = {'Data Diperbarui':['','','','','',''],'Makanan':['Makanan A','Makanan B','Makanan C','Makanan D','Makanan E','Makanan F'],'Stok Makanan':[5,5,5,5,5,5],'Harga Makanan':[20000,30000,40000,50000,60000,70000],
                    'Minuman':['Minuman A','Minuman B','Minuman C','Minuman D','Minuman E','Minuman F'],'Stok Minuman':[5,5,5,5,5,5],'Harga Minuman':[20000,30000,40000,50000,60000,70000],
                      'Snack':['Snack A','Snack B','Snack C','Snack D','Snack E','Snack F'],'Stok Snack':[5,5,5,5,5,5],'Harga Snack':[20000,30000,40000,50000,60000,70000]}
                    df =pd.DataFrame(data)
                    df.to_csv('data_stok.csv',index = False)
# Jika pada kolom jabatan terisi karyawan, maka akan ada beberapa data yang masuk dalam dictionary data.
# Selanjutnya, DataFrame dibuat dengan menggunakan pd.DataFrame(data) dengan menggunakan library pandas. DataFrame ini akan berisi data yang telah diatur dalam dictionary data.
# DataFrame kemudian disimpan ke file CSV dengan menggunakan metode .to_csv('data_stok.csv', index=False). Nama file CSV adalah 'data_stok.csv' dan index=False digunakan untuk tidak menyertakan indeks dalam file CSV.

                #message box!
                    messagebox.showinfo("Information!!", "Data Telah Di Simpan!!")
                def entry_barang():
                    def entry_updatestok(frame, x, y, text):
                        label = Label(frame, text=text, bg="#e2ddce", fg="#181b29", font=("Roboto Bold", 20, "bold"))
                        label.place(x=x, y=y)
                        entry = Entry(frame, highlightthickness=0, relief=RIDGE, bg="white", fg="#999999", font=("yu gothic ui", 20, "bold"),justify='center')
                        entry.place(x=x, y=y+35, width=30,height=30)
                        return entry
                    
   
                    def simpan_stok():  
                        if entry.get():
                            dataset = pd.read_csv ("data_stok.csv")

                        #membuat variabel waktu saat ini dengan datetime
                            a = dt.datetime.now()
                            waktu = a.strftime("%Y %B %d")
                            
                            #Ambil nilai value dari Entry
                            entry_makanan = [makanan.get() for makanan in self.value_makanan]
                            entry_minuman = [minuman.get() for minuman in self.value_minuman]
                            entry_snack = [snack.get() for snack in self.value_snack]
                            #Memasukan tanggal update data
                            for i in range(len(dataset)):
                                dataset.loc[i,'Data Diperbarui'] = waktu
                    # Jika nilai entry.get() ada, maka dilakukan pembacaan dataset dari file CSV yang disimpan dalam variabel dataset.
                    # Selanjutnya, dibuat variabel waktu yang berisi tanggal dan waktu saat ini menggunakan modul datetime.
                    # Nilai stok barang untuk makanan, minuman, dan snack diambil dari setiap Entry menggunakan list comprehensions dan
                    # disimpan dalam variabel entry_makanan, entry_minuman, dan entry_snack masing-masing.


                            #memasukan data makanan Baru
                            for i in range(len(dataset)):
                                dataset.loc[i,'Stok Makanan'] = entry_makanan[i]
                                
                            #Memasukan data Minuman Baru
                            for i in range(len(dataset)):
                                dataset.loc[i,'Stok Minuman'] = entry_minuman[i]
                                
                            #Memasukan data Snack Baru
                            for i in range(len(dataset)):
                                dataset.loc[i,'Stok Snack'] = entry_snack[i]
                            
                    
                            dataset.to_csv("data_stok.csv", index=False, header=True)
                            messagebox.showinfo("Information!!",'Data Telah Disimpann!!')
                        else:
                            self.wajib = Label(self.timpa, background='#f4eee0', text='*Semua entry harus di isi',
                                fg="#191825", font=("yu gothic ui", 12,'bold','italic'), relief=FLAT, width=49, height=1)
                            self.wajib.place(x=520, y=520)


                    #Latar belakang
                    self.timpa = Frame(self.timpa, bg='#f4eee0', width=1460, height=779)
                    self.timpa.place(x=0, y=0)
                    self.bgrn_image = ImageTk.PhotoImage(Image.open('gambar/bgrnupload.png'))
                    self.bgrnlabl= Label(self.timpa, image=self.bgrn_image, background="#ccc6ba").place(x=0, y=0)


                    def logoutacc():
                        def dest():
                            # messagebox.showinfo("Logout Berhasil")
                            self.dons.destroy()
                        
                        self.dons = customtkinter.CTkFrame(master=self.timpa, fg_color='#ccc6ba', width=200, height=110)
                        self.dons.place(x=1250, y=65)
                        self.batal=customtkinter.CTkButton(master=self.dons, text='↩',font=('Arial', 30), corner_radius=8, text_color="#181b29", fg_color="#ccc6ba", hover_color="#f4eee0", width=200, height=40, command=dest).place(x=1, y=6)
                        self.imglogacc = ImageTk.PhotoImage(Image.open('gambar/logoutacc.png'))
                        self.logoutacc1=customtkinter.CTkButton(master=self.dons, text='Logout', image=self.imglogacc,font=('Arial', 20), text_color="#181b29", corner_radius=14, width=200, height=40, fg_color="#ccc6ba", hover_color="#f4eee0", command=self.regispage).place(x=1, y=50)
                    self.imgacc = ImageTk.PhotoImage(Image.open('gambar/acc.png'))
                    self.logoutaccada=customtkinter.CTkButton(master=self.timpa, text=' ', image=self.imgacc,font=('Arial', 20), text_color="#181b29", corner_radius=8, width=50, height=40, fg_color="#ccc6ba", hover_color="#7a766f", command=logoutacc).place(x=1360, y=65)
                    # tombol Logout akan ditampilkan di tampilan utama, dan ketika diklik, akan muncul jendela konfirmasi 
                    # dan pengguna dapat membatalkan logout atau melanjutkan untuk logout dengan mengklik tombol "Logout"
                    
                    
                    #Button
                    self.simpnbtn=customtkinter.CTkButton(master=self.timpa, text='Simpan',font=('yu gothic ui', 20), text_color="white", corner_radius=13, width=500, height=50, fg_color="#191825", hover_color="#444352", command=simpan_stok).place(x=485, y=560)
                    self.backbtn=customtkinter.CTkButton(master=self.timpa, text='Kembali',font=('yu gothic ui', 20), text_color="white", corner_radius=13, width=210, height=50, fg_color="Red", hover_color="#ff4040", command=dedmart).place(x=140, y=670)   
                    
                    #Makanan
                    self.makanan_list = ["Makanan A", "Makanan B", "Makanan C", "Makanan D","Makanan E","Makanan F"]
                    self.value_makanan = []
                    frame = self.timpa
                    font=("yu gothic ui", 20, "bold")
                    x = 110
                    y = 250
                    
                    for makanan in self.makanan_list:
                        entry = entry_updatestok(frame, x, y, makanan)
                        self.value_makanan.append(entry)
                        x += 210 #Nilai x akan diperbarui agar entri berikutnya ditempatkan di sebelah kanan entri sebelumnya dengan jarak horizontal sebesar 210.
                    #kode tersebut akan membuat entri untuk setiap makanan dalam self.makanan_list
                    #dan menyimpan nilai-nilai entri tersebut dalam self.value_makanan untuk penggunaan selanjutnya
                        
                        
                    #Minuman
                    self.minuman_list = ["Minuman A", "Minuman B", "Minuman C", "Minuman D","Minuman E","Minuman F"]
                    self.value_minuman = []
                    x = 110
                    y = 335
                    
                    for minuman in self.minuman_list:
                        entry = entry_updatestok(frame, x, y, minuman)
                        self.value_minuman.append(entry)
                        x += 210
                        
                    #Snack
                    self.snack_list = ["Snack A", "Snack B", "Snack C", "Snack D","Snack E","Snack F"]
                    self.value_snack = []
                    x = 110
                    y = 420
                    
                    for snack in self.snack_list:
                        entry = entry_updatestok(frame, x, y, snack)
                        self.value_snack.append(entry)
                        x += 210
                self.timpa = Frame(self.window, bg='#f4eee0', width=1460, height=779)
                self.timpa.place(x=35, y=35)
                self.bgrn_image = ImageTk.PhotoImage(Image.open('gambar/bgrndedmart.png'))
                self.bgrnlabl= Label(self.timpa, image=self.bgrn_image, background="#ccc6ba").place(x=0, y=0)
                def logoutacc():
                        def dest():
                            # messagebox.showinfo("Logout Berhasil")
                            self.dons.destroy()
                        
                        self.dons = customtkinter.CTkFrame(master=self.timpa, fg_color='#ccc6ba', width=200, height=110)
                        self.dons.place(x=1250, y=65)
                        self.batal=customtkinter.CTkButton(master=self.dons, text='↩',font=('Arial', 30), corner_radius=8, text_color="#181b29", fg_color="#ccc6ba", hover_color="#f4eee0", width=200, height=40, command=dest).place(x=1, y=6)
                        self.imglogacc = ImageTk.PhotoImage(Image.open('gambar/logoutacc.png'))
                        self.logoutacc1=customtkinter.CTkButton(master=self.dons, text='Logout', image=self.imglogacc,font=('Arial', 20), text_color="#181b29", corner_radius=14, width=200, height=40, fg_color="#ccc6ba", hover_color="#f4eee0", command=self.regispage).place(x=1, y=50)
                self.imgacc = ImageTk.PhotoImage(Image.open('gambar/acc.png'))
                self.backbtn=customtkinter.CTkButton(master=self.timpa, text='Kembali',font=('yu gothic ui', 20), text_color="white", corner_radius=13, width=210, height=50, fg_color="Red", hover_color="#ff4040", command=self.mainpage).place(x=140, y=670)
                self.logoutaccada=customtkinter.CTkButton(master=self.timpa, text=' ', image=self.imgacc,font=('Arial', 20), text_color="#181b29", corner_radius=8, width=50, height=40, fg_color="#ccc6ba", hover_color="#7a766f", command=logoutacc).place(x=1360, y=65)
                def messkar():
                    messagebox.showinfo("Information!!","Opsi ini hanya bisa diakses oleh manajer")
                self.list_stokbarang = ["Makanan", "Minuman", "Snack"]
                self.stokbar_box = customtkinter.CTkComboBox(self.timpa, values=self.list_stokbarang,font=("yu gothic ui ", 25),width=360)
                self.stokbar_box.place(x=150, y=350)
                # self.lbltampilanstok = Label(self.timpa, bg="#f4eee0", width=90, height=18,relief=FLAT).place(x=630, y=330)
                # self.btntampilstok = Button(self.timpa, background='#f4eee0', padx=1, pady=10,activebackground='#f4eee0', text="Cek barang",font=('Roboto Bold', 25, ),relief=FLAT ,command=cek_barang ).place(x=230, y=430)
                self.imgcetak = ImageTk.PhotoImage(Image.open('gambar/imgcetak.png'))
                self.pengajuanrestok=customtkinter.CTkButton(master=self.timpa, image=self.imgcetak, text='Cetak Pengajuan',font=('Roboto Bold', 23), text_color="#181b29", corner_radius=14, width=340, height=85, fg_color="#f4eee0", hover_color="#f8f4ec", command=messkar).place(x=561, y=655)

                self.imgcek = ImageTk.PhotoImage(Image.open('gambar/imgcekbarang.png'))
                self.checkbtn=customtkinter.CTkButton(master=self.timpa, image=self.imgcek,text='Cek Barang',font=('Roboto Bold', 30), text_color="#181b29", corner_radius=14, width=385, height=110, fg_color="#f4eee0", hover_color="#f8f4ec", command=messkar).place(x=140, y=420)
                
                #Button template
                self.imgunduh = ImageTk.PhotoImage(Image.open('gambar/imgunduh.png'))
                self.imgupload = ImageTk.PhotoImage(Image.open('gambar/imgupload.png'))
                self.unduhtemplate=customtkinter.CTkButton(master=self.timpa, image=self.imgunduh, text='Unduh Template',font=('Roboto Bold', 25), text_color="#181b29", corner_radius=14, width=380, height=100, fg_color="#f4eee0", hover_color="#f8f4ec", command=template).place(x=140, y=187)

                self.uploadtemplate=customtkinter.CTkButton(master=self.timpa, image=self.imgupload,text='Entry data stok',font=('Roboto Bold', 25), text_color="#181b29", corner_radius=14, width=380, height=100, fg_color="#f4eee0", hover_color="#f8f4ec", command=entry_barang).place(x=924, y=186)

            elif dataset.jabatan[self.idx]=='Manajer':
                def cek_barang():
                    dataset = pd.read_csv('data_stok.csv')
                    #jika combobox yang dipilih untuk menampilkan makanan yang menipis
                    if self.stokbar_box.get() == 'Makanan':
                        #membuat frame timpa agar meminimalisi eror
                        self.frame_cekbarang = Frame(self.frame_cekbarang, bg='#f4eee0', width=700,  height=235).place(x=635, y=385)
                        
                        #membuat list dengan hasil pencarian
                        stok_makanan = []
                        stok_makanan_menipis = []
                        indeks_makanan_menipis = []
                        
                        #mencari value disetiap kolom dataset
                        for i in dataset['Stok Makanan']:
                            stok_makanan.append(i)
                        print(stok_makanan)

                        #mencari stok yang menipis dari value yang diambil dari dataset
                        for i in range(len(stok_makanan)):
                            if stok_makanan[i] <= 5:
                                stok_makanan_menipis.append(stok_makanan[i])
                        print(stok_makanan_menipis)

                        # Mencari indeks minuman mana yang menipis untuk ditampilkan
                        for i in range(len(stok_makanan)):
                            if stok_makanan[i] <= 5:
                                indeks_makanan_menipis.append(i)
                        print(indeks_makanan_menipis)
                        
                        #menampilkan data
                        for i in range(len(stok_makanan)):
                            if i in indeks_makanan_menipis:
                                if i == 0:
                                    self.label_showdata = Label(self.frame_cekbarang, background='#dbd6c9', text=f'Stok Makanan A tersisa\t{stok_makanan[i]}',
                                                                fg="#191825", font=("yu gothic ui", 12, 'bold', 'italic'), relief=FLAT, width=49, height=1)
                                    self.label_showdata.place(x=780, y=385)
                                elif i == 1:
                                    self.label_showdata = Label(self.frame_cekbarang, background='#dbd6c9', text=f'Stok Makanan B tersisa\t{stok_makanan[i]}',
                                                                fg="#191825", font=("yu gothic ui", 12, 'bold', 'italic'), relief=FLAT, width=49, height=1)
                                    self.label_showdata.place(x=780, y=415)
                                elif i == 2:
                                    self.label_showdata = Label(self.frame_cekbarang, background='#dbd6c9', text=f'Stok Makanan C tersisa\t{stok_makanan[i]}',
                                                                fg="#191825", font=("yu gothic ui", 12, 'bold', 'italic'), relief=FLAT, width=49, height=1)
                                    self.label_showdata.place(x=780, y=445)
                                elif i == 3:
                                    self.label_showdata = Label(self.frame_cekbarang, background='#dbd6c9', text=f'Stok Makanan D tersisa\t{stok_makanan[i]}',
                                                                fg="#191825", font=("yu gothic ui", 12, 'bold', 'italic'), relief=FLAT, width=49, height=1)
                                    self.label_showdata.place(x=780, y=475)
                                elif i == 4:
                                    self.label_showdata = Label(self.frame_cekbarang, background='#dbd6c9', text=f'Stok Makanan E tersisa\t{stok_makanan[i]}',
                                                                fg="#191825", font=("yu gothic ui", 12, 'bold', 'italic'), relief=FLAT, width=49, height=1)
                                    self.label_showdata.place(x=780, y=505)
                                elif i == 5:
                                    self.label_showdata = Label(self.frame_cekbarang, background='#dbd6c9', text=f'Stok Makanan F tersisa\t{stok_makanan[i]}',
                                                                fg="#191825", font=("yu gothic ui", 12, 'bold', 'italic'), relief=FLAT, width=49, height=1)
                                    self.label_showdata.place(x=780, y=535)
                            else:
                                if i == 0:
                                    self.label_showdata = Label(self.frame_cekbarang, background='#f4eee0', text='Stok Makanan A Masih Mencukupi!',
                                                                fg="#191825", font=("yu gothic ui", 12, 'bold', 'italic'), relief=FLAT, width=49, height=1)
                                    self.label_showdata.place(x=780, y=385)
                                elif i == 1:
                                    self.label_showdata = Label(self.frame_cekbarang, background='#f4eee0', text='Stok Makanan B Masih Mencukupi!',
                                                                fg="#191825", font=("yu gothic ui", 12, 'bold', 'italic'), relief=FLAT, width=49, height=1)
                                    self.label_showdata.place(x=780, y=415)
                                elif i == 2:
                                    self.label_showdata = Label(self.frame_cekbarang, background='#f4eee0', text='Stok Makanan C Masih Mencukupi!',
                                                                fg="#191825", font=("yu gothic ui", 12, 'bold', 'italic'), relief=FLAT, width=49, height=1)
                                    self.label_showdata.place(x=780, y=445)
                                elif i == 3:
                                    self.label_showdata = Label(self.frame_cekbarang, background='#f4eee0', text='Stok Makanan D Masih Mencukupi!',
                                                                fg="#191825", font=("yu gothic ui", 12, 'bold', 'italic'), relief=FLAT, width=49, height=1)
                                    self.label_showdata.place(x=780, y=475)
                                elif i == 4:
                                    self.label_showdata = Label(self.frame_cekbarang, background='#f4eee0', text='Stok Makanan E Masih Mencukupi!',
                                                                fg="#191825", font=("yu gothic ui", 12, 'bold', 'italic'), relief=FLAT, width=49, height=1)
                                    self.label_showdata.place(x=780, y=505)
                                elif i == 5:
                                    self.label_showdata = Label(self.frame_cekbarang, background='#f4eee0', text='Stok Makanan F Masih Mencukupi!',
                                                                fg="#191825", font=("yu gothic ui", 12, 'bold', 'italic'), relief=FLAT, width=49, height=1)
                                    self.label_showdata.place(x=780, y=535)
        
                    if self.stokbar_box.get() == 'Minuman':
                        #membuat frame timpa agar meminimalisi eror
                        self.frame_cekbarang = Frame(self.frame_cekbarang, bg='#f4eee0', width=700,  height=235).place(x=635, y=385)
                        
                        #membuat list dengan hasil pencarian
                        stok_minuman = []
                        stok_minuman_menipis = []
                        indeks_minuman_menipis = []

                        # Mencari value di setiap kolom dataset
                        for i in dataset['Stok Minuman']:
                            stok_minuman.append(i)
                        print(stok_minuman)

                        # Mencari stok yang menipis dari value yang diambil dari dataset
                        for i in range(len(stok_minuman)):
                            if stok_minuman[i] <= 5:
                                stok_minuman_menipis.append(stok_minuman[i])
                        print(stok_minuman_menipis)

                        # Mencari indeks minuman mana yang menipis untuk ditampilkan
                        for i in range(len(stok_minuman)):
                            if stok_minuman[i] <= 5:
                                indeks_minuman_menipis.append(i)
                        print(indeks_minuman_menipis)

                        # Menampilkan data
                        for i in range(len(stok_minuman)):
                            if i in indeks_minuman_menipis:
                                if i == 0:
                                    self.label_showdata = Label(self.frame_cekbarang, background='#dbd6c9', text=f'Stok Minuman A tersisa\t{stok_minuman[i]}',
                                                fg="#191825", font=("yu gothic ui", 12, 'bold', 'italic'), relief=FLAT, width=49, height=1)
                                    self.label_showdata.place(x=780, y=385)
                                
                                elif i == 1:
                                    self.label_showdata = Label(self.frame_cekbarang, background='#dbd6c9', text=f'Stok Minuman B tersisa\t{stok_minuman[i]}',
                                                                fg="#191825", font=("yu gothic ui", 12, 'bold', 'italic'), relief=FLAT, width=49, height=1)
                                    self.label_showdata.place(x=780, y=415)
                                
                                elif i == 2:
                                    self.label_showdata = Label(self.frame_cekbarang, background='#dbd6c9', text=f'Stok Minuman C tersisa\t{stok_minuman[i]}',
                                                                fg="#191825", font=("yu gothic ui", 12, 'bold', 'italic'), relief=FLAT, width=49, height=1)
                                    self.label_showdata.place(x=780, y=445)
                                
                                elif i == 3:
                                    self.label_showdata = Label(self.frame_cekbarang, background='#dbd6c9', text=f'Stok Minuman D tersisa\t{stok_minuman[i]}',
                                                                fg="#191825", font=("yu gothic ui", 12, 'bold', 'italic'), relief=FLAT, width=49, height=1)
                                    self.label_showdata.place(x=780, y=475)
                                
                                elif i == 4:
                                    self.label_showdata = Label(self.frame_cekbarang, background='#dbd6c9', text=f'Stok Minuman E tersisa\t{stok_minuman[i]}',
                                                                fg="#191825", font=("yu gothic ui", 12, 'bold', 'italic'), relief=FLAT, width=49, height=1)
                                    self.label_showdata.place(x=780, y=505)
                                
                                elif i == 5:
                                    self.label_showdata = Label(self.frame_cekbarang, background='#dbd6c9', text=f'Stok Minuman F tersisa\t{stok_minuman[i]}',
                                                                fg="#191825", font=("yu gothic ui", 12, 'bold', 'italic'), relief=FLAT, width=49, height=1)
                                    self.label_showdata.place(x=780, y=535)
                            else:
                                if i == 0:
                                    self.label_showdata = Label(self.frame_cekbarang, background='#f4eee0', text='Stok Minuman A Masih Mencukupi!',
                                                                fg="#191825", font=("yu gothic ui", 12, 'bold', 'italic'), relief=FLAT, width=49, height=1)
                                    self.label_showdata.place(x=780, y=385)
                                    
                                elif i == 1:
                                    self.label_showdata = Label(self.frame_cekbarang, background='#f4eee0', text='Stok Minuman B Masih Mencukupi!',
                                                            fg="#191825", font=("yu gothic ui", 12, 'bold', 'italic'), relief=FLAT, width=49, height=1)
                                    self.label_showdata.place(x=780, y=415)
                                    
                                elif i == 2:
                                    self.label_showdata = Label(self.frame_cekbarang, background='#f4eee0', text='Stok Minuman C Masih Mencukupi!',
                                                            fg="#191825", font=("yu gothic ui", 12, 'bold', 'italic'), relief=FLAT, width=49, height=1)
                                    self.label_showdata.place(x=780, y=445)
                                elif i == 3:
                                    self.label_showdata = Label(self.frame_cekbarang, background='#f4eee0', text='Stok Minuman D Masih Mencukupi!',
                                                            fg="#191825", font=("yu gothic ui", 12, 'bold', 'italic'), relief=FLAT, width=49, height=1)
                                    self.label_showdata.place(x=780, y=475)
                                elif i == 4:
                                    self.label_showdata = Label(self.frame_cekbarang, background='#f4eee0', text='Stok Minuman E Masih Mencukupi!',
                                                            fg="#191825", font=("yu gothic ui", 12, 'bold', 'italic'), relief=FLAT, width=49, height=1)
                                    self.label_showdata.place(x=780, y=505)
                                elif i == 5:
                                    self.label_showdata = Label(self.frame_cekbarang, background='#f4eee0', text='Stok Minuman F Masih Mencukupi!',
                                                            fg="#191825", font=("yu gothic ui", 12, 'bold', 'italic'), relief=FLAT, width=49, height=1)
                                    self.label_showdata.place(x=780, y=535)
            
                    if self.stokbar_box.get() == 'Snack':
                        #membuat frame timpa agar meminimalisi eror
                        self.frame_cekbarang = Frame(self.frame_cekbarang, bg='#f4eee0', width=700,  height=235).place(x=635, y=385)
                        
                        #membuat list dengan hasil pencarian
                        stok_snack = []
                        stok_snack_menipis = []
                        indeks_snack_menipis = []

                        # Mencari value di setiap kolom dataset
                        for i in dataset['Stok Snack']:
                            stok_snack.append(i)
                        print(stok_snack)

                        # Mencari stok yang menipis dari value yang diambil dari dataset
                        for i in range(len(stok_snack)):
                            if stok_snack[i] <= 5:
                                stok_snack_menipis.append(stok_snack[i])
                        print(stok_snack_menipis)

                        # Mencari indeks snack mana yang menipis untuk ditampilkan
                        for i in range(len(stok_snack)):
                            if stok_snack[i] <= 5:
                                indeks_snack_menipis.append(i)
                        print(indeks_snack_menipis)

                        # Menampilkan data
                        for i in range(len(stok_snack)):
                            if i in indeks_snack_menipis:
                                if i == 0:
                                    self.label_showdata = Label(self.frame_cekbarang, background='#dbd6c9', text=f'Stok Snack A tersisa\t{stok_snack[i]}',
                                                                fg="#191825", font=("yu gothic ui", 12, 'bold', 'italic'), relief=FLAT, width=49, height=1)
                                    self.label_showdata.place(x=780, y=385)
                                elif i == 1:
                                    self.label_showdata = Label(self.frame_cekbarang, background='#dbd6c9', text=f'Stok Snack B tersisa\t{stok_snack[i]}',
                                                                fg="#191825", font=("yu gothic ui", 12, 'bold', 'italic'), relief=FLAT, width=49, height=1)
                                    self.label_showdata.place(x=780, y=415)
                                elif i == 2:
                                    self.label_showdata = Label(self.frame_cekbarang, background='#dbd6c9', text=f'Stok Snack C tersisa\t{stok_snack[i]}',
                                                                fg="#191825", font=("yu gothic ui", 12, 'bold', 'italic'), relief=FLAT, width=49, height=1)
                                    self.label_showdata.place(x=780, y=445)
                                elif i == 3:
                                    self.label_showdata = Label(self.frame_cekbarang, background='#dbd6c9', text=f'Stok Snack D tersisa\t{stok_snack[i]}',
                                                                fg="#191825", font=("yu gothic ui", 12, 'bold', 'italic'), relief=FLAT, width=49, height=1)
                                    self.label_showdata.place(x=780, y=475)
                                elif i == 4:
                                    self.label_showdata = Label(self.frame_cekbarang, background='#dbd6c9', text=f'Stok Snack E tersisa\t{stok_snack[i]}',
                                                                fg="#191825", font=("yu gothic ui", 12, 'bold', 'italic'), relief=FLAT, width=49, height=1)
                                    self.label_showdata.place(x=780, y=505)
                                elif i == 5:
                                    self.label_showdata = Label(self.frame_cekbarang, background='#dbd6c9', text=f'Stok Snack F tersisa\t{stok_snack[i]}',
                                                                fg="#191825", font=("yu gothic ui", 12, 'bold', 'italic'), relief=FLAT, width=49, height=1)
                                    self.label_showdata.place(x=780, y=535)
                            else:
                                if i == 0:
                                    self.label_showdata = Label(self.frame_cekbarang, background='#f4eee0', text='Stok Snack A Masih Mencukupi!',
                                                                fg="#191825", font=("yu gothic ui", 12, 'bold', 'italic'), relief=FLAT, width=49, height=1)
                                    self.label_showdata.place(x=780, y=385)
                                elif i == 1:
                                    self.label_showdata = Label(self.frame_cekbarang, background='#f4eee0', text='Stok Snack B Masih Mencukupi!',
                                                                fg="#191825", font=("yu gothic ui", 12, 'bold', 'italic'), relief=FLAT, width=49, height=1)
                                    self.label_showdata.place(x=780, y=415)
                                elif i == 2:
                                    self.label_showdata = Label(self.frame_cekbarang, background='#f4eee0', text='Stok Snack C Masih Mencukupi!',
                                                                fg="#191825", font=("yu gothic ui", 12, 'bold', 'italic'), relief=FLAT, width=49, height=1)
                                    self.label_showdata.place(x=780, y=445)
                                elif i == 3:
                                    self.label_showdata = Label(self.frame_cekbarang, background='#f4eee0', text='Stok Snack D Masih Mencukupi!',
                                                                fg="#191825", font=("yu gothic ui", 12, 'bold', 'italic'), relief=FLAT, width=49, height=1)
                                    self.label_showdata.place(x=780, y=475)
                                elif i == 4:
                                    self.label_showdata = Label(self.frame_cekbarang, background='#f4eee0', text='Stok Snack E Masih Mencukupi!',
                                                                fg="#191825", font=("yu gothic ui", 12, 'bold', 'italic'), relief=FLAT, width=49, height=1)
                                    self.label_showdata.place(x=780, y=505)
                                elif i == 5:
                                    self.label_showdata = Label(self.frame_cekbarang, background='#f4eee0', text='Stok Snack F Masih Mencukupi!',
                                                                fg="#191825", font=("yu gothic ui", 12, 'bold', 'italic'), relief=FLAT, width=49, height=1)
                                    self.label_showdata.place(x=780, y=535)
                
                def suratpengajuan():
                    self.timpa = Frame(self.window, bg='#f4eee0', width=1460, height=779)
                    self.timpa.place(x=35, y=35)
                    self.bgrn_image = ImageTk.PhotoImage(Image.open('gambar/bgrnsrt.png'))
                    self.bgrnlabl= Label(self.timpa, image=self.bgrn_image, background="#ccc6ba").place(x=0, y=0)
                    def logoutacc():
                        def dest():
                            # messagebox.showinfo("Logout Berhasil")
                            self.dons.destroy()
                        
                        self.dons = customtkinter.CTkFrame(master=self.timpa, fg_color='#ccc6ba', width=200, height=110)
                        self.dons.place(x=1250, y=65)
                        self.batal=customtkinter.CTkButton(master=self.dons, text='↩',font=('Arial', 30), corner_radius=8, text_color="#181b29", fg_color="#ccc6ba", hover_color="#f4eee0", width=200, height=40, command=dest).place(x=1, y=6)
                        self.imglogacc = ImageTk.PhotoImage(Image.open('gambar/logoutacc.png'))
                        self.logoutacc1=customtkinter.CTkButton(master=self.dons, text='Logout', image=self.imglogacc,font=('Arial', 20), text_color="#181b29", corner_radius=14, width=200, height=40, fg_color="#ccc6ba", hover_color="#f4eee0", command=self.regispage).place(x=1, y=50)
                    self.imgacc = ImageTk.PhotoImage(Image.open('gambar/acc.png'))
                    self.logoutaccada=customtkinter.CTkButton(master=self.timpa, text=' ', image=self.imgacc,font=('Arial', 20), text_color="#181b29", corner_radius=8, width=50, height=40, fg_color="#ccc6ba", hover_color="#7a766f", command=logoutacc).place(x=1360, y=65)


                    nama=StringVar()

                    makanana=StringVar()
                    makananb=StringVar()
                    makananc=StringVar()
                    makanand=StringVar()
                    makanane=StringVar()
                    makananf=StringVar()

                    minumana=StringVar()
                    minumanb=StringVar()
                    minumanc=StringVar()
                    minumand=StringVar()
                    minumane=StringVar()
                    minumanf=StringVar()

                    snacka=StringVar()
                    snackb=StringVar()
                    snackc=StringVar()
                    snackd=StringVar()
                    snacke=StringVar()
                    snackf=StringVar()

                    def surat():
                        word=Document()
                        today = dt.datetime.now().strftime('%d %B %Y')
                        word.add_picture("gambar/kopsrt.png")
                        # word.add_heading("Surat Pengajuan Stok Barang", 0)
                        word.add_paragraph(f"\t\t\t\t\t\t\t\tSurabaya, {today}")
                        word.add_paragraph("Kepada Yth.")
                        word.add_paragraph("Direktur Pt. Ded Company")
                        word.add_paragraph("Gedung Vokasi")
                        word.add_paragraph("Surabaya")

                        word.add_paragraph("\nMelalui surat ini saya: ")

                        word.add_paragraph(f"\nNama\t:{nama.get()}")
                        word.add_paragraph("Jabatan\t:Manajer")

                        word.add_paragraph(f"\nSehubungan dengan batas stok minimal pada DED MART saya {nama.get()} selaku manajer perusahaan mengajukan permohonan anggaran dana suplai barang dengan rincian sebagai berikut:\n")

                        tabel_header=["Nama Barang", "Jumlah", "Harga Satuan"]
                        some_data= [
                            ["Makanan A", makanana.get(), "25000"],
                            ["Makanan B", makananb.get(), "30000"],
                            ["Makanan C", makananc.get(), "40000"],
                            ["Makanan D", makanand.get(), "50000"],
                            ["Makanan E", makanane.get(), "55000"],
                            ["Makanan F", makananf.get(), "60000"],

                            ["Minuman A", minumana.get(), "4000"],
                            ["Minuman B", minumanb.get(), "5000"],
                            ["Minuman C", minumanc.get(), "6000"],
                            ["Minuman D", minumand.get(), "8000"],
                            ["Minuman E", minumane.get(), "10000"],
                            ["Minuman F", minumanf.get(), "15000"],

                            ["Snack A", snacka.get(), "3000"],
                            ["Snack B", snackb.get(), "5000"],
                            ["Snack C", snackc.get(), "10000"],
                            ["Snack D", snackd.get(), "15000"],
                            ["Snack E", snacke.get(), "20000"],
                            ["Snack F", snackf.get(), "25000"]
                        ]
                        tabel=word.add_table(rows=1, cols=3)
                        for i in range(3):
                            tabel.rows[0].cells[i].text=tabel_header[i]

                        for namabarang, jumlah, harga in some_data:
                            cells=tabel.add_row().cells
                            cells[0].text=namabarang
                            cells[1].text=str(jumlah)
                            cells[2].text=harga

                        word.add_paragraph("\nDemikian surat permohonan barang ini dibuat. Terima kasih atas waktu dan perhatiannya.\n")

                        word.add_paragraph("\n_____________________")
                        word.add_paragraph({nama.get()})



                        word.save("suratpermohonan.docx")
                        messagebox.showinfo("Information!!",'Data telah disimpan sebagai Document!!')

                    self.nama_depan_label = Label(self.timpa, text="Nama", bg="#e2ddce", fg="#181b29",
                                        font=("Roboto Bold", 20, "bold"))
                    self.nama_depan_label.place(x=110, y=180)
                    self.nama_depan_entry = Entry(self.timpa,highlightthickness=0, textvariable=nama,relief=RIDGE, bg="white", fg="#999999",
                                                        font=("yu gothic ui", 25, "bold"))
                    self.nama_depan_entry.place(x=110, y=217, width=350, height=50)
                    self.simpanbtn=customtkinter.CTkButton(master=self.timpa, text='Simpan',font=('yu gothic ui', 20), text_color="white", corner_radius=13, width=500, height=50, fg_color="#191825", hover_color="#444352", command=surat).place(x=485, y=650)

                    self.entrylblMKNA = Label(self.timpa, text="Makanan A", bg="#e2ddce", fg="#181b29",
                                                        font=("Roboto Bold", 20, "bold")).place(x=110, y=300)
                    self.btnmakanA=customtkinter.CTkEntry(self.timpa ,font=('yu gothic ui', 20), text_color="#181b29", bg_color="#e2ddce",corner_radius=13, textvariable=makanana,width=57,height=30, fg_color="White").place(x=110, y=342)
                    self.entrylblMKNB = Label(self.timpa, text="Makanan B", bg="#e2ddce", fg="#181b29",
                                                        font=("Roboto Bold", 20, "bold")).place(x=320, y=300)
                    self.btnmakanB=customtkinter.CTkEntry(self.timpa ,font=('yu gothic ui', 20), text_color="#181b29", bg_color="#e2ddce",corner_radius=13, textvariable=makananb,width=57,height=30, fg_color="White").place(x=320, y=342)
                    self.entrylblMKNC = Label(self.timpa, text="Makanan C", bg="#e2ddce", fg="#181b29",
                                                        font=("Roboto Bold", 20, "bold")).place(x=530, y=300)
                    self.btnmakanC=customtkinter.CTkEntry(self.timpa ,font=('yu gothic ui', 20), text_color="#181b29", bg_color="#e2ddce",corner_radius=13, textvariable=makananc,width=57,height=30, fg_color="White").place(x=530, y=342)
                    self.entrylblMKND = Label(self.timpa, text="Makanan D", bg="#e2ddce", fg="#181b29",
                                                        font=("Roboto Bold", 20, "bold")).place(x=740, y=300)
                    self.btnmakanD=customtkinter.CTkEntry(self.timpa ,font=('yu gothic ui', 20), text_color="#181b29", bg_color="#e2ddce",corner_radius=13, textvariable=makanand,width=57,height=30, fg_color="White").place(x=740, y=342)
                    self.entrylblMKNE = Label(self.timpa, text="Makanan E", bg="#e2ddce", fg="#181b29",
                                                        font=("Roboto Bold", 20, "bold")).place(x=950, y=300)
                    self.btnmakanE=customtkinter.CTkEntry(self.timpa ,font=('yu gothic ui', 20), text_color="#181b29", bg_color="#e2ddce",corner_radius=13, textvariable=makanane,width=57,height=30, fg_color="White").place(x=950, y=342)
                    self.entrylblMKNF = Label(self.timpa, text="Makanan F", bg="#e2ddce", fg="#181b29",
                                                        font=("Roboto Bold", 20, "bold")).place(x=1160, y=300)
                    self.btnmakanF=customtkinter.CTkEntry(self.timpa ,font=('yu gothic ui', 20), text_color="#181b29", bg_color="#e2ddce",corner_radius=13, textvariable=makananf,width=57,height=30, fg_color="White").place(x=1160, y=342)

                    self.entrylblMINA = Label(self.timpa, text="Minuman A", bg="#e2ddce", fg="#181b29",
                                                        font=("Roboto Bold", 20, "bold")).place(x=110, y=410)
                    self.btnMINUMA=customtkinter.CTkEntry(self.timpa ,font=('yu gothic ui', 20), text_color="#181b29", bg_color="#e2ddce",corner_radius=13, textvariable=minumana,width=57,height=30, fg_color="White").place(x=110, y=452)
                    self.entrylblMINB = Label(self.timpa, text="Minuman B", bg="#e2ddce", fg="#181b29",
                                                        font=("Roboto Bold", 20, "bold")).place(x=320, y=410)
                    self.btnMINUMB=customtkinter.CTkEntry(self.timpa ,font=('yu gothic ui', 20), text_color="#181b29", bg_color="#e2ddce",corner_radius=13, textvariable=minumanb,width=57,height=30, fg_color="White").place(x=320, y=452)
                    self.entrylblMINC = Label(self.timpa, text="Minuman C", bg="#e2ddce", fg="#181b29",
                                                        font=("Roboto Bold", 20, "bold")).place(x=530, y=410)
                    self.btnMINUMC=customtkinter.CTkEntry(self.timpa ,font=('yu gothic ui', 20), text_color="#181b29", bg_color="#e2ddce",corner_radius=13, textvariable=minumanc,width=57,height=30, fg_color="White").place(x=530, y=452)
                    self.entrylblMIND = Label(self.timpa, text="Minuman D", bg="#e2ddce", fg="#181b29",
                                                        font=("Roboto Bold", 20, "bold")).place(x=740, y=410)
                    self.btnMINUMD=customtkinter.CTkEntry(self.timpa ,font=('yu gothic ui', 20), text_color="#181b29", bg_color="#e2ddce",corner_radius=13, textvariable=minumand,width=57,height=30, fg_color="White").place(x=740, y=452)
                    self.entrylblMINE = Label(self.timpa, text="Minuman E", bg="#e2ddce", fg="#181b29",
                                                        font=("Roboto Bold", 20, "bold")).place(x=950, y=410)
                    self.btnMINUME=customtkinter.CTkEntry(self.timpa ,font=('yu gothic ui', 20), text_color="#181b29", bg_color="#e2ddce",corner_radius=13, textvariable=minumane,width=57,height=30, fg_color="White").place(x=950, y=452)
                    self.entrylblMINF = Label(self.timpa, text="Minuman F", bg="#e2ddce", fg="#181b29",
                                                        font=("Roboto Bold", 20, "bold")).place(x=1160, y=410)
                    self.btnMINUMF=customtkinter.CTkEntry(self.timpa ,font=('yu gothic ui', 20), text_color="#181b29", bg_color="#e2ddce",corner_radius=13, textvariable=minumanf,width=57,height=30, fg_color="White").place(x=1160, y=452)

                    self.entrylblSNKA = Label(self.timpa, text="Snack A", bg="#e2ddce", fg="#181b29",
                                                        font=("Roboto Bold", 20, "bold")).place(x=110, y=515)
                    self.btnSNKA=customtkinter.CTkEntry(self.timpa ,font=('yu gothic ui', 20), text_color="#181b29", bg_color="#e2ddce",corner_radius=13, textvariable=snacka,width=57,height=30, fg_color="White").place(x=110, y=557)
                    self.entrylblSNKB = Label(self.timpa, text="Snack B", bg="#e2ddce", fg="#181b29",
                                                        font=("Roboto Bold", 20, "bold")).place(x=320, y=515)
                    self.btnSNKB=customtkinter.CTkEntry(self.timpa ,font=('yu gothic ui', 20), text_color="#181b29", bg_color="#e2ddce",corner_radius=13, textvariable=snackb,width=57,height=30, fg_color="White").place(x=320, y=557)
                    self.entrylblSNKC = Label(self.timpa, text="Snack C", bg="#e2ddce", fg="#181b29",
                                                        font=("Roboto Bold", 20, "bold")).place(x=530, y=515)
                    self.btnSNKC=customtkinter.CTkEntry(self.timpa ,font=('yu gothic ui', 20), text_color="#181b29", bg_color="#e2ddce",corner_radius=13, textvariable=snackc,width=57,height=30, fg_color="White").place(x=530, y=557)
                    self.entrylblSNKD = Label(self.timpa, text="Snack D", bg="#e2ddce", fg="#181b29",
                                                        font=("Roboto Bold", 20, "bold")).place(x=740, y=515)
                    self.btnSNKD=customtkinter.CTkEntry(self.timpa ,font=('yu gothic ui', 20), text_color="#181b29", bg_color="#e2ddce",corner_radius=13, textvariable=snackd,width=57,height=30, fg_color="White").place(x=740, y=557)
                    self.entrylblSNKE = Label(self.timpa, text="Snack E", bg="#e2ddce", fg="#181b29",
                                                        font=("Roboto Bold", 20, "bold")).place(x=950, y=515)
                    self.btnSNKE=customtkinter.CTkEntry(self.timpa ,font=('yu gothic ui', 20), text_color="#181b29", bg_color="#e2ddce",corner_radius=13, textvariable=snacke,width=57,height=30, fg_color="White").place(x=950, y=557)
                    self.entrylblSNKF = Label(self.timpa, text="Snack F", bg="#e2ddce", fg="#181b29",
                                                        font=("Roboto Bold", 20, "bold")).place(x=1160, y=515)
                    self.btnSNKF=customtkinter.CTkEntry(self.timpa ,font=('yu gothic ui', 20), text_color="#181b29", corner_radius=13, textvariable=snackf,width=57,height=30, fg_color="White").place(x=1160, y=557)
                    self.backbtn=customtkinter.CTkButton(master=self.timpa, text='Kembali',font=('yu gothic ui', 20), text_color="white", corner_radius=13, width=210, height=50, fg_color="Red", hover_color="#ff4040", command=dedmart).place(x=140, y=670)

                
                
                self.timpa = Frame(self.window, bg='#f4eee0', width=1460, height=779)
                self.timpa.place(x=35, y=35)
                self.bgrn_image = ImageTk.PhotoImage(Image.open('gambar/bgrndedmart.png'))
                self.bgrnlabl= Label(self.timpa, image=self.bgrn_image, background="#ccc6ba").place(x=0, y=0)
                #Button cek barang
                self.list_stokbarang = ["Makanan", "Minuman", "Snack"]
                # self.stokbar_box = ttk.Combobox(self.timpa, values=self.list_stokbarang,font=("yu gothic ui ", 25),width=19)
                # self.stokbar_box.place(x=150, y=350)
                self.frame_cekbarang = Frame(self.timpa, bg='#f4eee0', width=700,  height=235).place(x=600, y=350)
                def logoutacc():
                        def dest():
                            self.dons.destroy()
                        self.dons = customtkinter.CTkFrame(master=self.timpa, fg_color='#ccc6ba', width=200, height=110)
                        self.dons.place(x=1250, y=65)
                        self.batal=customtkinter.CTkButton(master=self.dons, text='↩',font=('Arial', 30), corner_radius=8,text_color="#181b29", fg_color="#ccc6ba", hover_color="#f4eee0", width=200, height=40, command=dest).place(x=1, y=6)
                        self.imglogacc = ImageTk.PhotoImage(Image.open('gambar/logoutacc.png'))
                        self.logoutacc1=customtkinter.CTkButton(master=self.dons, text='Logout', image=self.imglogacc,font=('Arial', 20), text_color="#181b29", corner_radius=14, width=200, height=40, fg_color="#ccc6ba", hover_color="#f4eee0", command=self.regispage).place(x=1, y=50)
                        
                self.imgacc = ImageTk.PhotoImage(Image.open('gambar/acc.png'))
                self.logoutaccada=customtkinter.CTkButton(master=self.timpa, text=' ', image=self.imgacc,font=('Arial', 20), text_color="#181b29", corner_radius=8, width=50, height=40, fg_color="#ccc6ba", hover_color="#7a766f", command=logoutacc).place(x=1360, y=65)

                self.stokbar_box = customtkinter.CTkComboBox(self.timpa, values=self.list_stokbarang,font=("yu gothic ui ", 25),width=360)
                self.stokbar_box.place(x=150, y=350)
                # self.lbltampilanstok = Label(self.timpa, bg="#f4eee0", width=90, height=18,relief=FLAT).place(x=630, y=330)
                # self.btntampilstok = Button(self.timpa, background='#f4eee0', padx=1, pady=10,activebackground='#f4eee0', text="Cek barang",font=('Roboto Bold', 25, ),relief=FLAT ,command=cek_barang ).place(x=230, y=430)
                self.imgcetak = ImageTk.PhotoImage(Image.open('gambar/imgcetak.png'))
                self.pengajuanrestok=customtkinter.CTkButton(master=self.timpa, image=self.imgcetak, text='Cetak Pengajuan',font=('Roboto Bold', 23), text_color="#181b29", corner_radius=14, width=340, height=85, fg_color="#f4eee0", hover_color="#f8f4ec", command=suratpengajuan).place(x=561, y=655)

                self.imgcek = ImageTk.PhotoImage(Image.open('gambar/imgcekbarang.png'))
                self.checkbtn=customtkinter.CTkButton(master=self.timpa, image=self.imgcek,text='Cek Barang',font=('Roboto Bold', 30), text_color="#181b29", corner_radius=14, width=385, height=110, fg_color="#f4eee0", hover_color="#f8f4ec", command=cek_barang).place(x=140, y=420)
                self.backbtn=customtkinter.CTkButton(master=self.timpa, text='Kembali',font=('yu gothic ui', 20), text_color="white", corner_radius=13, width=210, height=50, fg_color="Red", hover_color="#ff4040", command=self.mainpage).place(x=140, y=670)
                def messmen():
                    messagebox.showinfo("Information!!","Opsi ini hanya bisa diakses oleh karyawan")

                self.imgunduh = ImageTk.PhotoImage(Image.open('gambar/imgunduh.png'))
                self.imgupload = ImageTk.PhotoImage(Image.open('gambar/imgupload.png'))
                self.unduhtemplate=customtkinter.CTkButton(master=self.timpa, image=self.imgunduh, text='Unduh Template',font=('Roboto Bold', 25), text_color="#181b29", corner_radius=14, width=380, height=100, fg_color="#f4eee0", hover_color="#f8f4ec", command=messmen).place(x=140, y=187)
                

                self.uploadtemplate=customtkinter.CTkButton(master=self.timpa, image=self.imgupload,text='Upload Data Stok',font=('Roboto Bold', 25), text_color="#181b29", corner_radius=14, width=380, height=100, fg_color="#f4eee0", hover_color="#f8f4ec",command=messmen).place(x=924, y=186)
  
        if self.email_entry.get() and self.password_entry.get():
            # save to csv
            dataset = pd.read_csv('data_user1.csv')
            
            # Membuat list yg berisi semua email dan pw
            email = []

            for i in dataset.email:
                email.append(i)

            # Kondisi untuk cek email dan nomor telfon yang sesuai sesuai dengan email di dataset
            if self.email_entry.get() in email: 
                
                # Cara untuk mengetahui index dari email yg di input
                self.idx = email.index(self.email_entry.get()) 
               
                # Kondisi untuk cek password yg di input sama dgn password dataset
                if self.password_entry.get() == dataset.password[self.idx]:

                    #timpa next page
                    
                    self.timpa = Frame(self.window, bg='#f4eee0', width=1460, height=779)
                    self.timpa.place(x=35, y=35)
                    self.bgrn_image = ImageTk.PhotoImage(Image.open('gambar/bgrnpilusaha.png'))
                    self.bgrnlabl= Label(self.timpa, image=self.bgrn_image, background="#ccc6ba").place(x=0, y=0)

                    def logoutacc():
                        def dest():
                            self.dons.destroy()
                        self.dons = customtkinter.CTkFrame(master=self.timpa, fg_color='#ccc6ba', width=200, height=110)
                        self.dons.place(x=1250, y=65)
                        self.batal=customtkinter.CTkButton(master=self.dons, text='↩',font=('Arial', 30), corner_radius=8,text_color="#181b29", fg_color="#ccc6ba", hover_color="#f4eee0", width=200, height=40, command=dest).place(x=1, y=6)
                        self.imglogacc = ImageTk.PhotoImage(Image.open('gambar/logoutacc.png'))
                        self.logoutacc1=customtkinter.CTkButton(master=self.dons, text='Logout', image=self.imglogacc,font=('Arial', 20), text_color="#181b29", corner_radius=14, width=200, height=40, fg_color="#ccc6ba", hover_color="#f4eee0", command=self.regispage).place(x=1, y=50)
                        # messagebox.showinfo("Logout Berhasil")
                    self.imgacc = ImageTk.PhotoImage(Image.open('gambar/acc.png'))
                    self.logoutaccada=customtkinter.CTkButton(master=self.timpa, text=' ', image=self.imgacc,font=('Arial', 20), text_color="#181b29", corner_radius=8, width=50, height=40, fg_color="#ccc6ba", hover_color="#7a766f", command=logoutacc).place(x=1360, y=65)
                    
                    #messageboc comingsoon
                    def soon():
                        messagebox.showinfo("Information!!","Opsi ini akan segera hadir")
                    #Button Usaha Penjualan dan Label
                    self.soonimg = ImageTk.PhotoImage(Image.open('gambar/soon.png'))
                    self.marketimg = ImageTk.PhotoImage(Image.open('gambar/dedmarkt2.png'))
                    self.btnmarkt = customtkinter.CTkButton(self.timpa, text='',font=('Arial', 20),corner_radius=25,fg_color="#e2ddce", hover_color="#b4b0a4",  image=self.marketimg,  command=dedmart)
                    self.btnmarkt.place(x=170, y=205)

                    
                    self.btnsoon = customtkinter.CTkButton(master=self.timpa, text='', image=self.soonimg,font=('Arial', 20), text_color="#e2ddce", fg_color="#e4e0d2", hover_color="#b4b0a4", command=soon)
                    self.btnsoon.place(x=470, y=205)

                    self.btnsoon = customtkinter.CTkButton(master=self.timpa, text='', image=self.soonimg,font=('Arial', 20), text_color="#e2ddce", fg_color="#e4e0d2", hover_color="#b4b0a4", command=soon)
                    self.btnsoon.place(x=790, y=205)
                    
                    self.btnsoon = customtkinter.CTkButton(master=self.timpa, text='', image=self.soonimg,font=('Arial', 20), text_color="#e2ddce", fg_color="#e4e0d2", hover_color="#b4b0a4", command=soon)
                    self.btnsoon.place(x=1100, y=205)

                #jika email dan password yang dimasukan salah
                else:
                    self.wajib = Label(self.lg_frame, background='#e2ddce', text=' Email atau password yang anda masukkan salah ',        fg='red', font=("yu gothic ui", 10,'italic'), relief=FLAT, width=39, height=1)
                    self.wajib.place(x=610, y=460)
                    
            #jika email dan password yang dimasukkan salah
            else:
                self.wajib = Label(self.lg_frame, background='#e2ddce', text=' Email atau password yang anda masukkan salah ',        fg='red', font=("yu gothic ui", 10,'italic'), relief=FLAT, width=39, height=1)
                self.wajib.place(x=610, y=460)
                
        #Jika entry tidak terisi dengan benar   
        else:
            self.wajib = Label(self.lg_frame, background='#e2ddce', text='*Semua entry harus di isi',
                            fg="#191825", font=("yu gothic ui", 12,'bold','italic'), relief=FLAT, width=49, height=1)
            self.wajib.place(x=520, y=460)

window = Tk()
root = newproject(window)
root.regispage()
window.mainloop()
# Out:
# C:\Users\ela\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\customtkinter\windows\widgets\core_widget_classes\ctk_base_class.py:179: UserWarning: CTkButton Warning: Given image is not CTkImage but <class 'PIL.ImageTk.PhotoImage'>. Image can not be scaled on HighDPI displays, use CTkImage instead.
#
#   warnings.warn(f"{type(self).__name__} Warning: Given image is not CTkImage but {type(image)}. Image can not be scaled on HighDPI displays, use CTkImage instead.\n")
# C:\Users\ela\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\customtkinter\windows\widgets\core_widget_classes\ctk_base_class.py:179: UserWarning: CTkButton Warning: Given image is not CTkImage but <class 'PIL.ImageTk.PhotoImage'>. Image can not be scaled on HighDPI displays, use CTkImage instead.
#
# ...

# %%
import pandas as pd              # untuk membaca dan menyimpan csv

stok = pd.read_csv('data_stok.csv')
stok.head(20)
# Out:
#   Data Diperbarui    Makanan  Stok Makanan  Harga Makanan    Minuman  \
# 0    2023 June 08  Makanan A             5          20000  Minuman A
# 1    2023 June 08  Makanan B             6          30000  Minuman B
# 2    2023 June 08  Makanan C             5          40000  Minuman C
# 3    2023 June 08  Makanan D             2          50000  Minuman D
# 4    2023 June 08  Makanan E             5          60000  Minuman E
# 5    2023 June 08  Makanan F             6          70000  Minuman F
#
#    Stok Minuman  Harga Minuman    Snack  Stok Snack  Harga Snack
# 0             4          20000  Snack A           6        20000
# 1             5          30000  Snack B           4        30000
# 2             6          40000  Snack C           5        40000
# 3             8          50000  Snack D           6        50000
# 4             4          60000  Snack E           4        60000
# 5             9          70000  Snack F           5        70000

# %%
pip install exceptions
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement exceptions (from versions: none)
# ERROR: No matching distribution found for exceptions
